# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 587

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&units=metric&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        #Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all'] 
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
                    
# # Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gadzhiyevo
# Processing Record 2 of Set 1 | sao joao da barra
# Processing Record 3 of Set 1 | ketchikan
# Processing Record 4 of Set 1 | tsubata
# Processing Record 5 of Set 1 | barka'
# City not found. Skipping...
# Processing Record 6 of Set 1 | jayapura
# Processing Record 7 of Set 1 | midvagur
# Processing Record 8 of Set 1 | isiro
# Processing Record 9 of Set 1 | maxixe
# Processing Record 10 of Set 1 | blackmans bay
# Processing Record 11 of Set 1 | shimoda
# Processing Record 12 of Set 1 | santyoku
# Processing Record 13 of Set 1 | iqaluit
# Processing Record 14 of Set 1 | quelimane
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | invercargill
# Processing Record 17 of Set 1 | puerto natales
# Processing Record 18 of Set 1 | ilulissat
# Processing Record 19 of Set 1 | hyesan
# Processing Record 20 of Set 1 | isafjordur
# Processing Record 21 of Set 1 | aosta
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          558
# Lat           558
# Lng           558
# Max Temp      558
# Humidity      558
# Cloudiness    558
# Wind Speed    558
# Country       558
# Date          558
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         gadzhiyevo  69.2551   33.3362    -16.07        96         100
# 1  sao joao da barra -21.6403  -41.0511     27.05        87           3
# 2          ketchikan  55.3422 -131.6461      0.26        93         100
# 3            tsubata  36.6667  136.7333      2.32        83          99
# 4           jayapura  -2.5333  140.7000     24.66        93         100
#
#    Wind Speed Country        Date
# 0        3.27      RU  1705400928
# 1        5.10      BR  1705400877
# 2        1.54      US  1705401153
# 3        2.31      JP  1705401153
# 4        1.19      ID  1705401153

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               gadzhiyevo  69.2551   33.3362    -16.07        96         100
# 1        sao joao da barra -21.6403  -41.0511     27.05        87           3
# 2                ketchikan  55.3422 -131.6461      0.26        93         100
# 3                  tsubata  36.6667  136.7333      2.32        83          99
# 4                 jayapura  -2.5333  140.7000     24.66        93         100
#
#          Wind Speed Country        Date
# City_ID
# 0              3.27      RU  1705400928
# 1              5.10      BR  1705400877
# 2              1.54      US  1705401153
# 3              2.31      JP  1705401153
# 4              1.19      ID  1705401153

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_lat = city_data_df['Lat']
y_temp = city_data_df['Max Temp']
plt.scatter(x_lat,y_temp,edgecolors='black', marker='o', alpha=0.8)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('City Max Latitude vs. Temperature')
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_lat = city_data_df['Lat']
y_humid = city_data_df['Humidity']
plt.scatter(x_lat,y_humid,edgecolors='black', marker='o', alpha=0.8)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity')
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_lat = city_data_df['Lat']
y_cloud = city_data_df['Cloudiness']
plt.scatter(x_lat,y_cloud,edgecolors='black', marker='o', alpha=0.8)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('City Latitude vs. Cloudiness')
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_lat = city_data_df['Lat']
y_wind = city_data_df['Wind Speed']
plt.scatter(x_lat,y_wind,edgecolors='black', marker='o', alpha=0.8)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('City Latitude vs. Wind Speed')
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, xlabel, ylabel):
    
    #linear regression, regress values, line equation string
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    print(f'The r value is: {r_value}')
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    #annotation position
    y_range = max(y_values) - min(y_values)
    x_position = min(x_values)
    y_position = min(y_values) + 0.55 * y_range
    # Label plot and annotate the line equation
    plt.scatter(x_values, y_values, marker='o', alpha=0.8)
    plt.plot(x_values, regress_values, 'r-')
    plt.annotate(line_eq,(x_position,y_position),fontsize=15,color="red")
    #labeling
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        gadzhiyevo  69.2551   33.3362    -16.07        96         100
# 2         ketchikan  55.3422 -131.6461      0.26        93         100
# 3           tsubata  36.6667  136.7333      2.32        83          99
# 5          midvagur  62.0511   -7.1939     -1.54        74         100
# 6             isiro   2.7739   27.6160     34.19        16          44
#
#          Wind Speed Country        Date
# City_ID
# 0              3.27      RU  1705400928
# 2              1.54      US  1705401153
# 3              2.31      JP  1705401153
# 5              9.77      FO  1705401154
# 6              1.66      CD  1705401154

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        sao joao da barra -21.6403  -41.0511     27.05        87           3
# 4                 jayapura  -2.5333  140.7000     24.66        93         100
# 7                   maxixe -23.8597   35.3472     32.90        62          40
# 8            blackmans bay -43.0167  147.3167     23.07        57          67
# 12               quelimane -17.8786   36.8883     33.97        59          75
#
#          Wind Speed Country        Date
# City_ID
# 1              5.10      BR  1705400877
# 4              1.19      ID  1705401153
# 7              6.69      MZ  1705401154
# 8              2.33      AU  1705400869
# 12             1.54      MZ  1705401156

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], 'Latitude', 'Temperature')
# Out:
# The r value is: -0.8846322281680629

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], 'Latitude', 'Temperature')
# Out:
# The r value is: 0.6103120536270618

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern Hemisphere, there is a noticeable negative correlation between maximum temperature and latitude. Conversely, in the Southern Hemisphere, a positive correlation is observed between maximum temperature and latitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], 'Latitude', 'Humidity')
# Out:
# The r value is: 0.4710701610270888

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], 'Latitude', 'Humidity')
# Out:
# The r value is: 0.18731014448955272

# %% [markdown]
# **Discussion about the linear relationship:** Both plots show a positive correlation between humidity and latitude. However,
# the correlation is relatively weak in both cases, with evidence of small r values and regression coefficients

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], 'Latitude', 'Cloudiness')
# Out:
# The r value is: 0.38752736376604185

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], 'Latitude', 'Cloudiness')
# Out:
# The r value is: 0.2741607190424966

# %% [markdown]
# **Discussion about the linear relationship:** Both plots show a positive correlation between Loudiness and latitude, but the strength of the correlation is also relatively weak. There could be other factors that affect the cloudiness in latitudes.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed')
# Out:
# The r value is: 0.04202321690193385

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed')
# Out:
# The r value is: -0.1606124680677358

# %% [markdown]
# **Discussion about the linear relationship:** In both plots, the r values are close to 0, and the regression lines are nearly flat. This suggests a weak, or even no, linear relationship between wind speed and latitude.
